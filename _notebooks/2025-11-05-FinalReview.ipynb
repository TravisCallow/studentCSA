# %% [markdown]
# ---
# layout: post
# title: Retrospective
# description: Trimester One Retrospective
# permalink: /personalReviews/finalReview
# author: Travis Callow
# ---

# %% [markdown]
# # What Has Changed
# ### Before The Trimester
# - I didn't understand too much about cooperation and working on projects with other people as previous projects we had different sections divided up
# - I didn't know too much about local storage and saving progress
# - I didn't know much about OOP
# - I didn't know much about JSON
#
# ### Ending of the Trimester
# - I know how to communicate and work in my team
# - I know how to use local storage effectively
# - I know how to use OOP and use it effectively
# - I know how to use JSON and when to use it like storing in local storage.
# - I also learned how to implement JSON into Roblox development

# %% [markdown]
# # Key Things From the Past 3 Sprints
#
# ### Sprint 1: Tools
# - Using VSCode properly and effectively with Github
# - Learn to build websites
#
# ### Sprint 2: Fundamentals of JavaScript/Python
# - Learning how to user JavaScript and Python
# - Learning how to set up Spring
# - Learning how to use OOP and JPA
#
# ### Sprint 3: Profile/LinkedIn Quest
# - Learning how to make a lesson
# - Learning how to properly teach something, don't use a lot of text, rather make it like a game or lots of interactivity with less words.

# %% [markdown]
# # N@TM: How Did it Go?
#
# - N@TM went well, had good interactions with people and parents.
# - Alex Rubio's parents commented how it was good, they liked the Postman simulator
#
# <img src="{{site.baseurl}}/images/nightmuseum1.jpg">

# %% [markdown]
# # Plans for Future
#
# ### Project I Want To Do Next:
# I want to make either a game or a shopping website. Given 3 weeks to work on either.
# - For the game, I would like for it to be multiplayer and maybe like a top-down shooter game or something of that sorts.
# - For the shopping website I would want it to be like a clothing store or product store.
#
# ### What to Learn Next in CompSci:
# I want to learn how to make purchase features so I can make a shop to make some money.

# %% [markdown]
# # MCQ
# #### I did not do as good as I wanted to, I didn't have much time to do it as I was studying a lot for my math final.
#
# <img src="{{site.baseurl}}/images/horriblemcq.png">

# %% [markdown]
# # Something Cool
# Something cool I would like to share is that I am working on a way better study game on Roblox, it will have a bunch more utilities people can use to help with their academic career and it will have games and more features to it.
